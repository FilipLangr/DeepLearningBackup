# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3082, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  loss_sg = []
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    loss_sg.append(l)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.486813
# Average loss at step 2000: 4.366661
# Average loss at step 4000: 3.861103
# Average loss at step 6000: 3.786284
# Average loss at step 8000: 3.686143
# Average loss at step 10000: 3.615332
# Average loss at step 12000: 3.606009
# Average loss at step 14000: 3.562861
# Average loss at step 16000: 3.412970
# Average loss at step 18000: 3.450287
# Average loss at step 20000: 3.541716
# Average loss at step 22000: 3.502415
# Average loss at step 24000: 3.487151
# Average loss at step 26000: 3.479077
# Average loss at step 28000: 3.478454
# Average loss at step 30000: 3.508887
# Average loss at step 32000: 3.499008
# Average loss at step 34000: 3.500542
# Average loss at step 36000: 3.457440
# Average loss at step 38000: 3.300373
# Average loss at step 40000: 3.427146
# Average loss at step 42000: 3.439984
# Average loss at step 44000: 3.453097
# Average loss at step 46000: 3.453986
# Average loss at step 48000: 3.354097
# Average loss at step 50000: 3.385870
# Average loss at step 52000: 3.434361
# Average loss at step 54000: 3.423350
# Average loss at step 56000: 3.434399
# Average loss at step 58000: 3.398859
# Average loss at step 60000: 3.392711
# Average loss at step 62000: 3.244024
# Average loss at step 64000: 3.257305
# Average loss at step 66000: 3.402649
# Average loss at step 68000: 3.394262
# Average loss at step 70000: 3.365399
# Average loss at step 72000: 3.375963
# Average loss at step 74000: 3.349595
# Average loss at step 76000: 3.324044
# Average loss at step 78000: 3.350663
# Average loss at step 80000: 3.377003
# Average loss at step 82000: 3.406811
# Average loss at step 84000: 3.412798
# Average loss at step 86000: 3.391964
# Average loss at step 88000: 3.349306
# Average loss at step 90000: 3.365007
# Average loss at step 92000: 3.397652
# Average loss at step 94000: 3.259284
# Average loss at step 96000: 3.359078
# Average loss at step 98000: 3.234213
# Average loss at step 100000: 3.364921

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_CBOW(batch_size, skip_window):
  # skip_window: number of words that we consider left or right from the word.
  global data_index
  batch = np.ndarray(shape=(batch_size, 2*skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = []
  
  # First, fill the sliding window ("buffer") with a span of words.
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  
  # Move the sliding window, batch on i-th position contains span-1 == 2*skip_window words.
  # labels on i-th position has the word in the middle.
  # Go through the data until the whole batch is full.
  for i in range(batch_size):
    batch[i] = buffer[:skip_window] + buffer[skip_window+1:]
    labels[i] = buffer[skip_window]
    del buffer[0]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('some data:', [reverse_dictionary[di] for di in data[:10]])

# Let's look on the data for several skip_windows.
for skip_window in [4]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=8, skip_window=skip_window)
    print('\nwith span = %d:' % (2*skip_window))
    for ind, span in enumerate(batch):
        print('    batch:', [reverse_dictionary[wrd] for wrd in span])
        print('    label:', [reverse_dictionary[labels.reshape(8)[ind]]])
        print('')
# Out:
# some data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with span = 8:
#     batch: ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#     label: ['term']
#
#     batch: ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#     label: ['of']
#
#     batch: ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#     label: ['abuse']
#
#     batch: ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#     label: ['first']
#
#     batch: ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#     label: ['used']
#
#     batch: ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#     label: ['against']
#
#     batch: ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#     label: ['early']
#
#     batch: ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']
#     label: ['working']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data, mind the dimension of train_dataset.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print('embed shape before reduce_sum: %s' % embed.shape)
  # Now we have to sum the embeddings (accros axis 1), this dimension is 2*skip_window.
  embed = tf.reduce_sum(embed, 1)
  print('embed shape after reduce_sum: %s' % embed.shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embed shape before reduce_sum: (128, 2, 128)
# embed shape after reduce_sum: (128, 128)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  loss_c = []
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_CBOW(batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    loss_c.append(l)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.482233
# Nearest to been: brokered, retard, secretion, spoke, deliberation, hollow, playa, archaeologists,
# Nearest to was: avatar, amman, contagion, fez, pep, observers, flinders, semiautomatic,
# Nearest to i: cvs, eritrea, odes, posed, looming, somerset, dean, mistaking,
# Nearest to its: export, interwar, transcendentalism, estampie, cady, gx, masonry, critic,
# Nearest to nine: dart, immortal, pods, hibiscus, gama, mackinac, akhenaten, squeezing,
# Nearest to new: gypsum, spielberg, waltz, boolean, adventist, squealer, meshech, vre,
# Nearest to first: sandhi, tutor, unicode, ecb, republics, survival, performed, klein,
# Nearest to and: trojan, cordial, irredentism, sally, terminology, valuation, fathom, destroys,
# Nearest to history: nitrox, cayenne, prevails, climb, falstaff, renegades, hai, capitulated,
# Nearest to one: parkinson, west, spaniel, peikoff, drones, singing, managua, limiting,
# Nearest to a: overland, mechanized, selena, masurian, falk, brentwood, smoking, mbe,
# Nearest to would: scandinavia, fulfilment, condom, stallion, nationalized, positrons, cinderella, griff,
# Nearest to an: filkers, jalal, separatist, peanut, stratosphere, messina, saloons, duane,
# Nearest to when: saarc, displeased, jarry, bodies, griese, matti, arias, bianchi,
# Nearest to more: pompey, hellish, compact, fuzes, pendragon, formalised, homophobia, maggiore,
# Nearest to had: lui, markedly, nineteen, amenable, sublime, reza, flavouring, bordeaux,
# Average loss at step 2000: 4.128611
# Average loss at step 4000: 3.543078
# Average loss at step 6000: 3.412501
# Average loss at step 8000: 3.362050
# Average loss at step 10000: 3.216814
# Nearest to been: defender, internationals, cascade, be, was, sha, lined, himalaya,
# Nearest to was: is, were, had, has, be, became, been, heterochromatin,
# Nearest to i: ii, anglicised, somerset, wrestled, wojciech, they, we, cvs,
# Nearest to its: their, his, the, export, loon, hus, kitten, limbaugh,
# Nearest to nine: six, five, seven, four, zero, eight, three, two,
# Nearest to new: raymond, vre, quisling, woolen, alpha, laterally, matter, tigray,
# Nearest to first: second, appreciate, same, buddhism, rushdie, endocarditis, unicode, bluebird,
# Nearest to and: or, gokturks, for, but, including, overcomes, abeken, chalukyas,
# Nearest to history: badge, cordial, study, nitrox, list, ypres, view, mobilizing,
# Nearest to one: two, three, seven, six, nine, four, five, yogurt,
# Nearest to a: the, plowing, monaghan, longrightarrow, no, tonga, emissions, salon,
# Nearest to would: can, will, may, must, could, should, did, does,
# Nearest to an: filkers, preclear, quotation, stratosphere, simultaneity, rationalize, clintons, halld,
# Nearest to when: before, during, stadtholder, where, radcliffe, peninsular, perpetually, pivotal,
# Nearest to more: less, marsh, most, hellish, mehr, pompey, cc, diverting,
# Nearest to had: has, have, was, were, fcc, marvellous, biosynthesis, deacon,
# Average loss at step 12000: 3.270031
# Average loss at step 14000: 3.141981
# Average loss at step 16000: 3.076726
# Average loss at step 18000: 2.660400
# Average loss at step 20000: 2.830617
# Nearest to been: become, was, be, internationals, defender, lined, improved, were,
# Nearest to was: is, had, has, became, were, been, terrace, rulebase,
# Nearest to i: you, ii, we, they, anglicised, venomous, trolley, eritrea,
# Nearest to its: their, his, her, the, mauritanian, this, kitten, loon,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to new: sodom, tacit, vre, waste, adventist, tigray, responses, lessened,
# Nearest to first: second, last, next, third, anarchism, same, only, modernism,
# Nearest to and: or, but, including, guantanamo, american, which, who, delusional,
# Nearest to history: list, cordial, stanhope, study, badge, bradbury, ypres, view,
# Nearest to one: two, three, four, six, seven, five, nine, residue,
# Nearest to a: the, another, longrightarrow, plowing, masurian, no, every, timbuktu,
# Nearest to would: will, can, may, could, must, should, might, did,
# Nearest to an: filkers, preclear, simultaneity, specialists, stratosphere, quotation, polycarbonate, smashing,
# Nearest to when: before, during, after, where, if, although, while, radcliffe,
# Nearest to more: less, most, marsh, very, praxis, fitzgerald, pompey, hellish,
# Nearest to had: has, have, was, were, having, is, became, scriptural,
# Average loss at step 22000: 2.967724
# Average loss at step 24000: 2.954741
# Average loss at step 26000: 3.059106
# Average loss at step 28000: 3.023075
# Average loss at step 30000: 2.814936
# Nearest to been: become, be, internationals, defender, improved, was, lined, multimate,
# Nearest to was: is, had, has, were, became, be, peppermint, been,
# Nearest to i: we, ii, you, they, anglicised, wojciech, trolley, oddly,
# Nearest to its: their, his, her, your, our, the, convergence, kitten,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to new: sodom, launch, tacit, vre, waste, finance, contae, newnode,
# Nearest to first: last, second, next, third, anarchism, same, mmorpgs, syncopation,
# Nearest to and: or, including, itis, taney, anticipate, begging, but, featuring,
# Nearest to history: list, stanhope, view, flamenco, milit, period, badge, fraud,
# Nearest to one: two, six, four, seven, five, eight, residue, three,
# Nearest to a: another, the, no, longrightarrow, contexts, magenta, mechanized, subtracting,
# Nearest to would: will, could, can, must, may, should, might, did,
# Nearest to an: filkers, taxon, preclear, declassified, halld, smashing, wenders, unchanging,
# Nearest to when: if, while, where, although, before, during, because, stadtholder,
# Nearest to more: less, most, very, marsh, quite, hellish, smaller, pompey,
# Nearest to had: has, have, was, having, were, biosynthesis, refused, scriptural,
# Average loss at step 32000: 2.985432
# Average loss at step 34000: 3.013494
# Average loss at step 36000: 2.962970
# Average loss at step 38000: 2.682701
# Average loss at step 40000: 2.852606
# Nearest to been: become, be, internationals, improved, were, already, recently, was,
# Nearest to was: is, had, became, were, has, rulebase, did, solf,
# Nearest to i: ii, we, you, iii, they, he, acrylic, anglicised,
# Nearest to its: their, his, the, her, your, our, whose, convergence,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to new: tacit, launch, waste, vre, ccg, sodom, adventist, cluetrain,
# Nearest to first: last, second, next, third, mmorpgs, same, only, original,
# Nearest to and: or, including, but, taney, while, include, anticipate, overcomes,
# Nearest to history: list, study, eyewitness, clutching, milit, view, outbreak, period,
# Nearest to one: two, four, three, five, seven, six, residue, eight,
# Nearest to a: another, the, any, no, magenta, plowing, every, dialectal,
# Nearest to would: could, will, can, must, should, may, might, did,
# Nearest to an: filkers, preclear, stratosphere, riso, xyz, wenders, reversion, advancements,
# Nearest to when: if, before, although, while, where, after, until, though,
# Nearest to more: less, most, very, larger, quite, relatively, smaller, extremely,
# Nearest to had: has, have, was, having, were, ever, refused, scriptural,
# Average loss at step 42000: 2.764139
# Average loss at step 44000: 2.952190
# Average loss at step 46000: 2.787014
# Average loss at step 48000: 2.904562
# Average loss at step 50000: 2.882209
# Nearest to been: become, be, internationals, recently, improved, was, were, already,
# Nearest to was: is, had, became, were, has, becomes, racket, be,
# Nearest to i: we, ii, you, iii, they, wojciech, she, iv,
# Nearest to its: their, his, her, the, your, convergence, our, loon,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to new: fondation, waste, tacit, sodom, ccg, response, newnode, finance,
# Nearest to first: last, second, third, next, only, final, syncopation, sixth,
# Nearest to and: or, including, but, anticipate, grammaticus, taney, buzzing, touchdown,
# Nearest to history: study, list, milit, stanhope, flamenco, clutching, period, trick,
# Nearest to one: two, five, three, seven, eight, four, nine, six,
# Nearest to a: another, no, any, interment, divinities, extremely, calcio, hasten,
# Nearest to would: will, could, can, should, must, may, might, did,
# Nearest to an: preclear, filkers, polycarbonate, simultaneity, wenders, quotation, prick, stratosphere,
# Nearest to when: if, although, where, before, though, while, however, after,
# Nearest to more: less, most, very, quite, faster, longer, relatively, smaller,
# Nearest to had: has, have, was, having, were, recently, refused, scriptural,
# Average loss at step 52000: 2.850014
# Average loss at step 54000: 2.788094
# Average loss at step 56000: 2.845634
# Average loss at step 58000: 2.683747
# Average loss at step 60000: 2.821265
# Nearest to been: become, be, internationals, already, were, recently, gone, improved,
# Nearest to was: is, were, became, has, had, cameroonian, ellipses, be,
# Nearest to i: ii, we, iii, iv, you, medulla, apollos, workmanship,
# Nearest to its: their, his, her, the, your, our, loon, factorials,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to new: different, sodom, response, newnode, microcomputer, hyperspace, mourners, tacit,
# Nearest to first: last, second, next, third, final, sixth, ninth, same,
# Nearest to and: or, including, but, although, however, villiers, taney, while,
# Nearest to history: list, milit, flamenco, study, clutching, stanhope, period, life,
# Nearest to one: two, seven, eight, six, four, three, nine, five,
# Nearest to a: another, mechanized, plowing, alerting, subtracting, quite, septimius, no,
# Nearest to would: will, could, should, must, can, may, might, shall,
# Nearest to an: filkers, xyz, reversion, wenders, polycarbonate, bryn, tapped, another,
# Nearest to when: if, where, during, while, before, after, though, because,
# Nearest to more: less, most, greater, very, quite, faster, better, relatively,
# Nearest to had: has, have, having, was, were, took, refused, recently,
# Average loss at step 62000: 2.770766
# Average loss at step 64000: 2.847857
# Average loss at step 66000: 2.830389
# Average loss at step 68000: 2.660823
# Average loss at step 70000: 2.829130
# Nearest to been: become, be, internationals, were, already, was, existed, remained,
# Nearest to was: is, became, had, has, were, becomes, remained, been,
# Nearest to i: we, you, ii, iii, medulla, she, apollos, he,
# Nearest to its: their, his, her, the, your, whose, convergence, dreadnought,
# Nearest to nine: eight, six, seven, five, four, zero, three, two,
# Nearest to new: previous, cplp, hyperspace, golden, tigray, contae, launch, former,
# Nearest to first: last, second, next, third, final, ninth, original, same,
# Nearest to and: or, but, aka, while, villiers, barry, although, maynard,
# Nearest to history: list, study, milit, stanhope, period, trick, eyewitness, tradition,
# Nearest to one: two, four, six, three, five, eight, seven, nine,
# Nearest to a: another, the, longrightarrow, ruthenia, masurian, baleen, aristotelian, angelos,
# Nearest to would: will, could, should, might, can, must, may, shall,
# Nearest to an: filkers, xyz, wenders, reversion, stratosphere, sounded, another, mcghee,
# Nearest to when: if, where, before, while, after, though, during, although,
# Nearest to more: less, most, longer, very, quite, greater, larger, better,
# Nearest to had: has, have, was, having, refused, never, were, contains,
# Average loss at step 72000: 2.822595
# Average loss at step 74000: 2.792179
# Average loss at step 76000: 2.770432
# Average loss at step 78000: 2.806313
# Average loss at step 80000: 2.747117
# Nearest to been: become, be, were, remained, internationals, already, was, previously,
# Nearest to was: is, had, became, were, has, becomes, been, although,
# Nearest to i: we, ii, iii, you, iv, intersystems, they, g,
# Nearest to its: their, his, the, whose, her, your, our, convergence,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to new: previous, waste, sodom, launch, particular, newnode, modern, shortening,
# Nearest to first: last, second, next, third, final, ninth, best, latter,
# Nearest to and: or, but, including, although, however, while, taney, rett,
# Nearest to history: list, study, milit, periods, clutching, development, origins, rabbinic,
# Nearest to one: two, seven, four, three, five, six, eight, nine,
# Nearest to a: another, the, divinities, interment, masurian, plowing, unabated, macht,
# Nearest to would: will, could, can, should, may, might, must, cannot,
# Nearest to an: filkers, preclear, advancements, wenders, reversion, tapped, xyz, riso,
# Nearest to when: if, before, while, after, though, during, although, where,
# Nearest to more: less, most, quite, very, rather, greater, larger, relatively,
# Nearest to had: has, have, was, having, refused, gave, yet, recently,
# Average loss at step 82000: 2.584188
# Average loss at step 84000: 2.769490
# Average loss at step 86000: 2.744217
# Average loss at step 88000: 2.741899
# Average loss at step 90000: 2.768440
# Nearest to been: become, be, internationals, already, remained, recently, was, previously,
# Nearest to was: is, became, were, becomes, had, has, being, been,
# Nearest to i: ii, we, iii, you, iv, checkpoint, acrylic, medulla,
# Nearest to its: their, his, the, your, her, our, whose, convergence,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to new: previous, newnode, cluetrain, sodom, contae, vre, different, enumeration,
# Nearest to first: second, last, next, third, final, best, same, ninth,
# Nearest to and: or, but, while, although, including, outbound, itis, aka,
# Nearest to history: list, clutching, milit, flamenco, origins, politics, periods, study,
# Nearest to one: two, seven, three, six, five, four, eight, scarecrow,
# Nearest to a: another, the, every, mechanized, masurian, subtracting, any, zimmermann,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to an: filkers, preclear, simultaneity, wenders, rationalize, sounded, quizzes, xyz,
# Nearest to when: if, before, while, though, during, after, where, since,
# Nearest to more: less, most, quite, very, greater, faster, rather, smaller,
# Nearest to had: has, have, having, was, were, refused, never, habermas,
# Average loss at step 92000: 2.809666
# Average loss at step 94000: 2.762055
# Average loss at step 96000: 2.786167
# Average loss at step 98000: 2.692698
# Average loss at step 100000: 2.695588
# Nearest to been: become, be, already, remained, recently, internationals, previously, bougainville,
# Nearest to was: is, became, has, had, were, becomes, lakatos, seems,
# Nearest to i: ii, you, we, iv, iii, g, venomous, reserving,
# Nearest to its: their, his, our, whose, your, her, the, factorials,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to new: newnode, specific, contae, previous, tigray, different, enumeration, henley,
# Nearest to first: last, next, second, third, final, ninth, fourth, sixth,
# Nearest to and: or, but, although, including, taney, called, etc, outbound,
# Nearest to history: list, stanhope, flamenco, rabbinic, milit, clutching, trick, selection,
# Nearest to one: two, seven, four, five, eight, six, three, zero,
# Nearest to a: another, the, any, masurian, subtracting, dimitri, transshipment, asphyxiation,
# Nearest to would: will, could, might, should, can, may, must, cannot,
# Nearest to an: filkers, wenders, preclear, diagnosed, simultaneity, the, stratosphere, rationalize,
# Nearest to when: if, while, before, during, although, where, after, though,
# Nearest to more: less, very, quite, most, greater, highly, faster, better,
# Nearest to had: has, have, refused, having, was, were, ever, took,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
each = 1000
loss_c_avg = []
for i in range(0, len(loss_c), each):
    loss_c_avg.append(sum(loss_c[i:i+each])/each)
del loss_c_avg[-1]
loss_sg_avg = []
for i in range(0, len(loss_sg), each):
    loss_sg_avg.append(sum(loss_sg[i:i+each])/each)
del loss_sg_avg[-1]
import matplotlib.pyplot as plt
steps = np.arange(len(loss_c_avg))
_, ax = plt.subplots()
ax.plot(steps, loss_sg_avg, 'red', label="skip gram")
ax.plot(steps, loss_c_avg, 'green', label="CBOW")
legend = ax.legend()
ax.set_xlabel('step x%d' % each)
ax.set_ylabel('average loss')
plt.show()
